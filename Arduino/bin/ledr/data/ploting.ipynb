# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')

# %%
df = pd.read_csv("data5.csv")

# %%
d = df[df['Timestamp']<47500000]

# %%
df
# Out:
#      Timestamp  LED    Vi       Vo        LUX
# 0         1040    0  0.00  3.88563  107.65164
# 1         9004    0  0.00  3.89052  108.65242
# 2        16956    0  0.00  3.91984  114.92648
# 3        24948    0  0.00  3.92962  117.12606
# 4        32952    0  0.00  3.90029  110.69150
# 5        40940    0  0.00  3.87586  105.68698
# 6        48948    0  0.00  3.88563  107.65164
# 7        56948    0  0.00  3.91984  114.92648
# 8        64940    0  0.00  3.92962  117.12606
# 9        72944    0  0.00  3.90029  110.69150
# 10       80940    0  0.00  3.88074  106.66329
# 11       88932    0  0.00  3.88563  107.65164
# 12       96932    0  0.00  3.91984  114.92648
# 13      104924    0  0.00  3.93451  118.24715
# 14      112988    0  0.00  3.91007  112.78225
# 15      121040    0  0.00  3.88074  106.66329
# 16      129100    0  0.00  3.88563  107.65164
# 17      137152    0  0.00  3.91496  113.84758
# 18      145196    0  0.00  3.93451  118.24715
# ...

# %%
d.plot(x='Timestamp', y=['LUX'])
# Out:
# c:\users\fanm\appdata\local\programs\python\python36-32\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
